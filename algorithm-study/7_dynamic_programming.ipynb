# %% [markdown]
# <a href="https://colab.research.google.com/github/wlgns222/ROKA/blob/main/algorithm-study/7_dynamic_programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PART7 - Dynamic Programming**

# %% [markdown]
# ## Dynamic Programming

# %% [markdown]
# ### 1003번 피보나치 함수
#
# 다음 소스는 N번째 피보나치 수를 구하는 C++ 함수이다.
#
# ```
# int fibonacci(int n) {
#     if (n == 0) {
#         printf("0");
#         return 0;
#     } else if (n == 1) {
#         printf("1");
#         return 1;
#     } else {
#         return fibonacci(n‐1) + fibonacci(n‐2);
#     }
# }
# ```
#
#  N이 주어졌을 때, fibonacci(N)을 호출했을 때, 0과 1이 각각 몇 번 출력되는지 구하는 프로그램을 작성하시오.

# %%
import sys

zero = [0] * 41
one = [0] * 41

zero[0], one[0] = 1, 0
zero[1], one[1] = 0, 1

for i in range(2, 41) :
  zero[i] = zero[i-1] + zero[i-2]
  one[i] = one[i-1] + one[i-2]

t = int(sys.stdin.readline())

for _ in range(t) :
  n =  int(sys.stdin.readline())
  print(zero[n], one[n])

# %% [markdown]
# ### 1463번 1로 만들기
#
# 정수 X에 사용할 수 있는 연산은 다음과 같이 세 가지 이다.
#
# - X가 3으로 나누어 떨어지면, 3으로 나눈다.
# - X가 2로 나누어 떨어지면, 2로 나눈다.
# - 1을 뺀다.
#
# 정수 N이 주어졌을 때, 위와 같은 연산 세 개를 적절히 사용해서 1을 만들려고 한다. 연산을 사용하는 횟수의 최솟값을 출력하시오.

# %%
import sys

n = int(sys.stdin.readline())
toOne = [0] * (n+1)

for i in range(2, n+1) :
  toOne[i] = toOne[i-1] + 1
  if i % 2 == 0 :
    toOne[i] = min(toOne[i], toOne[i//2] + 1)
  if i % 3 == 0 :
    toOne[i] = min(toOne[i], toOne[i//3] + 1)

print(toOne[n])

# %% [markdown]
# ### 9095번 1,2,3 더하기

# %% [markdown]
# ### 2579번 계단 오르기

# %% [markdown]
# ### 1149번 RGB거리

# %% [markdown]
# ### 1932번 정수 삼각형

# %% [markdown]
# ### 11053번 가장 긴 증가하는 부분 수열

# %% [markdown]
# ## Dijkstra

# %% [markdown]
# ### 1446번 지름길

# %% [markdown]
# ### 18352번 특정 거리의 도시 찾기

# %% [markdown]
# ### 1753번 최단 경로
